# %%
import sqlite3
import pandas as pd

# %%
print("SQLite Connected Successfully")
# Out:
# SQLite Connected Successfully

# %%
import sqlite3

conn = sqlite3.connect("../sql/superstore.db")

print("Database Connected Successfully")
# Out:
# Database Connected Successfully

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\gudla\ApexPlanet_Internship\notebooks

# %%
import sqlite3

conn = sqlite3.connect(r"C:\Users\gudla\Downloads\superstore.db")

print("Connected to Downloads database")
# Out:
# Connected to Downloads database

# %%
import pandas as pd

pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)
# Out:
#                  name
# 0  cleaned_superstore

# %%
query = "SELECT * FROM cleaned_superstore LIMIT 5"

df = pd.read_sql(query, conn)

df
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 2       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 2   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 3  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 4  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
query = """
SELECT
    Category,
    ROUND(SUM(Sales), 2) AS Total_Sales
FROM cleaned_superstore
GROUP BY Category
ORDER BY Total_Sales DESC
"""

result = pd.read_sql(query, conn)

result
# Out:
#           Category  Total_Sales
# 0  Office Supplies    343425.00
# 1        Furniture    247379.44
# 2       Technology    228415.35

# %%
query = """
SELECT
    Region,
    ROUND(SUM(Profit), 2) AS Total_Profit
FROM cleaned_superstore
GROUP BY Region
ORDER BY Total_Profit DESC
"""

result = pd.read_sql(query, conn)

result
# Out:
#     Region  Total_Profit
# 0     West      45885.51
# 1     East      28025.69
# 2    South      22150.04
# 3  Central       2654.65

# %% [markdown]
# # Task 2 Summary
#
# ## Objectives Completed
#
# 1.Imported cleaned dataset into SQLite database
# 2.Performed SQL data extraction and analysis
# 3.Executed business queries using SQL
# 4.Implemented Subqueries, CTEs, and Views
# 5.Connected Python with SQLite database
# 6.Executed SQL queries using Pandas
#
# ## Key Learnings
#
# 1. Database creation and management using SQLite.
# 2. SQL querying for business analytics.
# 3. Advanced SQL concepts such as Subqueries, CTEs, and Views.
# 4. Integration of Python with SQL databases.
# 5. Data extraction and analysis using Pandas.
